# %%
from catboost import Pool, CatBoostClassifier
import numpy as np
from emnist import extract_training_samples, list_datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, classification_report

# %%
list_of_datasets = list_datasets()

images, labels = extract_training_samples('letters')
images = np.reshape(images, (images.shape[0], -1))
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.33, random_state=42)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.33, random_state=42)

print(images.shape)
# Out:
# (124800, 784)

# %%
from sklearn.model_selection import KFold, cross_val_score

kfold = KFold(n_splits=5, random_state=42, shuffle=True)

train_dataset = Pool(data=X_train,
                     label=y_train)

val_dataset = Pool(data=X_val,
                   label=y_val)

test_dataset = Pool(data=X_test,
                    label=y_test)

model = CatBoostClassifier(iterations=1000,
                           learning_rate=0.1,
                           depth=6,
                           loss_function='MultiClass',
                           eval_metric='AUC')

model.fit(train_dataset,
          eval_set=val_dataset)

preds_class = model.predict(test_dataset)

print(classification_report(y_test, preds_class))
# Out:
# 0:	test: 0.9177024	best: 0.9177024 (0)	total: 3.86s	remaining: 1h 4m 13s
# 1:	test: 0.9454550	best: 0.9454550 (1)	total: 7.81s	remaining: 1h 4m 57s
# 2:	test: 0.9575718	best: 0.9575718 (2)	total: 11.8s	remaining: 1h 5m 19s
# 3:	test: 0.9653552	best: 0.9653552 (3)	total: 15.7s	remaining: 1h 5m 10s
# 4:	test: 0.9695595	best: 0.9695595 (4)	total: 19.8s	remaining: 1h 5m 34s
# 5:	test: 0.9738970	best: 0.9738970 (5)	total: 25.2s	remaining: 1h 9m 30s
# 6:	test: 0.9767735	best: 0.9767735 (6)	total: 31.5s	remaining: 1h 14m 24s
# 7:	test: 0.9792494	best: 0.9792494 (7)	total: 38.2s	remaining: 1h 18m 52s
# 8:	test: 0.9807577	best: 0.9807577 (8)	total: 43.7s	remaining: 1h 20m 15s
# 9:	test: 0.9827207	best: 0.9827207 (9)	total: 48.1s	remaining: 1h 19m 23s
# 10:	test: 0.9838430	best: 0.9838430 (10)	total: 52s	remaining: 1h 17m 58s
# 11:	test: 0.9851535	best: 0.9851535 (11)	total: 56.1s	remaining: 1h 16m 57s
# 12:	test: 0.9863300	best: 0.9863300 (12)	total: 1m	remaining: 1h 16m 18s
# 13:	test: 0.9870484	best: 0.9870484 (13)	total: 1m 4s	remaining: 1h 15m 45s
# 14:	test: 0.9877644	best: 0.9877644 (14)	total: 1m 8s	remaining: 1h 15m 3s
# 15:	test: 0.9883854	best: 0.9883854 (15)	total: 1m 12s	remaining: 1h 14m 32s
# 16:	test: 0.9889245	best: 0.9889245 (16)	total: 1m 16s	remaining: 1h 13m 50s
# 17:	test: 0.9895836	best: 0.9895836 (17)	total: 1m 20s	remaining: 1h 13m 11s
# 18:	test: 0.9901690	best: 0.9901690 (18)	total: 1m 24s	remaining: 1h 12m 41s
# 19:	test: 0.9905886	best: 0.9905886 (19)	total: 1m 28s	remaining: 1h 12m 22s
# 20:	test: 0.9908862	best: 0.9908862 (20)	total: 1m 32s	remaining: 1h 12m 3s
# 21:	test: 0.9910888	best: 0.9910888 (21)	total: 1m 37s	remaining: 1h 11m 56s
# 22:	test: 0.9914037	best: 0.9914037 (22)	total: 1m 41s	remaining: 1h 11m 50s
# 23:	test: 0.9917026	best: 0.9917026 (23)	total: 1m 45s	remaining: 1h 11m 37s
# 24:	test: 0.9920159	best: 0.9920159 (24)	total: 1m 49s	remaining: 1h 11m 25s
# 25:	test: 0.9922860	best: 0.9922860 (25)	total: 1m 53s	remaining: 1h 11m 3s
# 26:	test: 0.9924235	best: 0.9924235 (26)	total: 1m 57s	remaining: 1h 10m 42s
# 27:	test: 0.9926385	best: 0.9926385 (27)	total: 2m 1s	remaining: 1h 10m 27s
# 28:	test: 0.9928041	best: 0.9928041 (28)	total: 2m 5s	remaining: 1h 10m 8s
# 29:	test: 0.9929260	best: 0.9929260 (29)	total: 2m 9s	remaining: 1h 9m 53s
# 30:	test: 0.9931268	best: 0.9931268 (30)	total: 2m 13s	remaining: 1h 9m 37s
# 31:	test: 0.9932890	best: 0.9932890 (31)	total: 2m 17s	remaining: 1h 9m 24s
# 32:	test: 0.9935036	best: 0.9935036 (32)	total: 2m 21s	remaining: 1h 9m 8s
# 33:	test: 0.9936308	best: 0.9936308 (33)	total: 2m 25s	remaining: 1h 8m 51s
# 34:	test: 0.9937692	best: 0.9937692 (34)	total: 2m 29s	remaining: 1h 8m 37s
# 35:	test: 0.9938643	best: 0.9938643 (35)	total: 2m 33s	remaining: 1h 8m 24s
# 36:	test: 0.9940380	best: 0.9940380 (36)	total: 2m 37s	remaining: 1h 8m 17s
# 37:	test: 0.9941922	best: 0.9941922 (37)	total: 2m 41s	remaining: 1h 8m 4s
# 38:	test: 0.9943127	best: 0.9943127 (38)	total: 2m 45s	remaining: 1h 7m 50s
# 39:	test: 0.9944336	best: 0.9944336 (39)	total: 2m 49s	remaining: 1h 7m 43s
# 40:	test: 0.9945052	best: 0.9945052 (40)	total: 2m 53s	remaining: 1h 7m 36s
# 41:	test: 0.9945806	best: 0.9945806 (41)	total: 2m 57s	remaining: 1h 7m 25s
# 42:	test: 0.9946820	best: 0.9946820 (42)	total: 3m 1s	remaining: 1h 7m 18s
# 43:	test: 0.9948120	best: 0.9948120 (43)	total: 3m 5s	remaining: 1h 7m 14s
# 44:	test: 0.9949048	best: 0.9949048 (44)	total: 3m 9s	remaining: 1h 7m 4s
# 45:	test: 0.9949894	best: 0.9949894 (45)	total: 3m 13s	remaining: 1h 6m 53s
# 46:	test: 0.9950715	best: 0.9950715 (46)	total: 3m 17s	remaining: 1h 6m 42s
# 47:	test: 0.9951337	best: 0.9951337 (47)	total: 3m 21s	remaining: 1h 6m 32s
# 48:	test: 0.9951961	best: 0.9951961 (48)	total: 3m 25s	remaining: 1h 6m 23s
# 49:	test: 0.9952934	best: 0.9952934 (49)	total: 3m 29s	remaining: 1h 6m 16s
# 50:	test: 0.9953844	best: 0.9953844 (50)	total: 3m 33s	remaining: 1h 6m 9s
# 51:	test: 0.9954246	best: 0.9954246 (51)	total: 3m 37s	remaining: 1h 6m 1s
# 52:	test: 0.9954791	best: 0.9954791 (52)	total: 3m 41s	remaining: 1h 5m 54s
# 53:	test: 0.9955430	best: 0.9955430 (53)	total: 3m 45s	remaining: 1h 5m 48s
# 54:	test: 0.9956042	best: 0.9956042 (54)	total: 3m 49s	remaining: 1h 5m 42s
# 55:	test: 0.9956728	best: 0.9956728 (55)	total: 3m 53s	remaining: 1h 5m 37s
# 56:	test: 0.9957135	best: 0.9957135 (56)	total: 3m 58s	remaining: 1h 5m 42s
# 57:	test: 0.9957565	best: 0.9957565 (57)	total: 4m 4s	remaining: 1h 6m 15s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_21479/3572041513.py in <module>
#      19
#      20 model.fit(train_dataset,
# ---> 21           eval_set=val_dataset)
#      22
#      23 preds_class = model.predict(test_dataset)
#
# ~/obwesos/venv/lib/python3.7/site-packages/catboost/core.py in fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    4921         self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    4922                   eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period,
# -> 4923                   silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    4924         return self
#    4925
#
# ~/obwesos/venv/lib/python3.7/site-packages/catboost/core.py in _fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2195                 params,
#    2196                 allow_clear_pool,
# -> 2197                 train_params["init_model"]
#    2198             )
#    2199
#
# ~/obwesos/venv/lib/python3.7/site-packages/catboost/core.py in _train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1617
#    1618     def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1619         self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1620         self._set_trained_model_attributes()
#    1621
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
# from sklearn.model_selection import KFold, cross_val_score
#
# kfold = KFold(n_splits=5, random_state=42, shuffle=True)
#
# # train_dataset = Pool(data=X_train,
# #                      label=y_train)
# #
# # val_dataset = Pool(data=X_val,
# #                    label=y_val)
# #
# # test_dataset = Pool(data=X_test,
# #                     label=y_test)
#
# # model = CatBoostClassifier(iterations=100,
# #                            learning_rate=0.1,
# #                            depth=4)
# #
# # model.fit(train_dataset, eval_set=val_dataset)
#
# # accuracies = cross_val_score(estimator=model, X=X_train, y=y_train, cv=5)
#
# # cv_results = cross_val_score(model, X_train, y_train,
# #                              cv=5, scoring='accuracy', verbose=1)
#
# for train_index, test_index in kfold.split(X_train):
#     train_dataset = Pool(data=X_train[train_index],
#                          label=y_train[train_index])
#
#     eval_dataset = Pool(data=X_train[test_index],
#                         label=y_train[test_index])
#
#     model = CatBoostClassifier(iterations=100,
#                                learning_rate=0.1,
#                                depth=6,
#                                eval_metric='AUC')
#
#     # cv_results = cross_val_score(model, X_train[train_index], y_train,
#     #                              cv=5, scoring='accuracy', verbose=1)
#
#     model.fit(train_dataset,
#               eval_set=eval_dataset)
#
#     train_score = model.score(X_train[train_index], y_train[train_index])  # train (learn) score
#     val_score = model.score(X_train[test_index], y_train[test_index])  # val (test) score
#
#     print(train_score)
#     print(val_score)
#
# # preds_class = model.predict(train_dataset)
#
# Out:
# 0:	learn: 2.9361182	test: 2.9381295	best: 2.9381295 (0)	total: 1.19s	remaining: 1m 57s
# 1:	learn: 2.7231820	test: 2.7239290	best: 2.7239290 (1)	total: 2.39s	remaining: 1m 57s
# 2:	learn: 2.5561960	test: 2.5587172	best: 2.5587172 (2)	total: 3.57s	remaining: 1m 55s
# 3:	learn: 2.4295437	test: 2.4345741	best: 2.4345741 (3)	total: 4.76s	remaining: 1m 54s
# 4:	learn: 2.3138671	test: 2.3204778	best: 2.3204778 (4)	total: 5.94s	remaining: 1m 52s
# 5:	learn: 2.2141173	test: 2.2223585	best: 2.2223585 (5)	total: 7.15s	remaining: 1m 51s
# 6:	learn: 2.1289078	test: 2.1402526	best: 2.1402526 (6)	total: 8.33s	remaining: 1m 50s
# 7:	learn: 2.0485206	test: 2.0614546	best: 2.0614546 (7)	total: 9.53s	remaining: 1m 49s
# 8:	learn: 1.9768627	test: 1.9917471	best: 1.9917471 (8)	total: 10.7s	remaining: 1m 48s
# 9:	learn: 1.9087541	test: 1.9245849	best: 1.9245849 (9)	total: 11.9s	remaining: 1m 46s
# 10:	learn: 1.8440233	test: 1.8603825	best: 1.8603825 (10)	total: 13s	remaining: 1m 45s
# 11:	learn: 1.7872889	test: 1.8043234	best: 1.8043234 (11)	total: 14.2s	remaining: 1m 44s
# 12:	learn: 1.7348984	test: 1.7528314	best: 1.7528314 (12)	total: 15.4s	remaining: 1m 43s
# 13:	learn: 1.6894655	test: 1.7086931	best: 1.7086931 (13)	total: 16.6s	remaining: 1m 41s
# 14:	learn: 1.6458334	test: 1.6655770	best: 1.6655770 (14)	total: 17.8s	remaining: 1m 40s
# 15:	learn: 1.6028289	test: 1.6240248	best: 1.6240248 (15)	total: 19s	remaining: 1m 39s
# 16:	learn: 1.5652889	test: 1.5878375	best: 1.5878375 (16)	total: 20.1s	remaining: 1m 38s
# 17:	learn: 1.5260763	test: 1.5497861	best: 1.5497861 (17)	total: 21.3s	remaining: 1m 37s
# 18:	learn: 1.4905027	test: 1.5149847	best: 1.5149847 (18)	total: 22.5s	remaining: 1m 35s
# 19:	learn: 1.4603877	test: 1.4865154	best: 1.4865154 (19)	total: 23.7s	remaining: 1m 34s
# 20:	learn: 1.4287843	test: 1.4563084	best: 1.4563084 (20)	total: 24.8s	remaining: 1m 33s
# 21:	learn: 1.3979712	test: 1.4267055	best: 1.4267055 (21)	total: 26s	remaining: 1m 32s
# 22:	learn: 1.3714327	test: 1.4008907	best: 1.4008907 (22)	total: 27.2s	remaining: 1m 31s
# 23:	learn: 1.3436930	test: 1.3746600	best: 1.3746600 (23)	total: 28.5s	remaining: 1m 30s
# 24:	learn: 1.3195693	test: 1.3514260	best: 1.3514260 (24)	total: 29.7s	remaining: 1m 28s
# 25:	learn: 1.2938411	test: 1.3260559	best: 1.3260559 (25)	total: 30.9s	remaining: 1m 27s
# 26:	learn: 1.2658259	test: 1.2988198	best: 1.2988198 (26)	total: 32s	remaining: 1m 26s
# 27:	learn: 1.2432005	test: 1.2772652	best: 1.2772652 (27)	total: 33.2s	remaining: 1m 25s
# 28:	learn: 1.2208278	test: 1.2560763	best: 1.2560763 (28)	total: 34.4s	remaining: 1m 24s
# 29:	learn: 1.2014580	test: 1.2380588	best: 1.2380588 (29)	total: 35.6s	remaining: 1m 23s
# 30:	learn: 1.1833801	test: 1.2214362	best: 1.2214362 (30)	total: 36.8s	remaining: 1m 21s
# 31:	learn: 1.1592957	test: 1.1976492	best: 1.1976492 (31)	total: 37.9s	remaining: 1m 20s
# 32:	learn: 1.1390827	test: 1.1788010	best: 1.1788010 (32)	total: 39.1s	remaining: 1m 19s
# 33:	learn: 1.1238082	test: 1.1644656	best: 1.1644656 (33)	total: 40.4s	remaining: 1m 18s
# 34:	learn: 1.1087897	test: 1.1501718	best: 1.1501718 (34)	total: 41.6s	remaining: 1m 17s
# 35:	learn: 1.0943197	test: 1.1365923	best: 1.1365923 (35)	total: 42.7s	remaining: 1m 15s
# 36:	learn: 1.0806600	test: 1.1233283	best: 1.1233283 (36)	total: 43.9s	remaining: 1m 14s
# 37:	learn: 1.0649961	test: 1.1084566	best: 1.1084566 (37)	total: 45.1s	remaining: 1m 13s
# 38:	learn: 1.0508750	test: 1.0951945	best: 1.0951945 (38)	total: 46.2s	remaining: 1m 12s
# 39:	learn: 1.0373164	test: 1.0822872	best: 1.0822872 (39)	total: 47.4s	remaining: 1m 11s
# 40:	learn: 1.0259186	test: 1.0714066	best: 1.0714066 (40)	total: 48.6s	remaining: 1m 9s
# 41:	learn: 1.0152908	test: 1.0611192	best: 1.0611192 (41)	total: 49.8s	remaining: 1m 8s
# 42:	learn: 1.0003863	test: 1.0476400	best: 1.0476400 (42)	total: 51s	remaining: 1m 7s
# 43:	learn: 0.9887282	test: 1.0365957	best: 1.0365957 (43)	total: 52.2s	remaining: 1m 6s
# 44:	learn: 0.9782091	test: 1.0270761	best: 1.0270761 (44)	total: 53.5s	remaining: 1m 5s
# 45:	learn: 0.9684910	test: 1.0180102	best: 1.0180102 (45)	total: 54.7s	remaining: 1m 4s
# 46:	learn: 0.9547096	test: 1.0046309	best: 1.0046309 (46)	total: 56.2s	remaining: 1m 3s
# 47:	learn: 0.9458689	test: 0.9965062	best: 0.9965062 (47)	total: 57.5s	remaining: 1m 2s
# 48:	learn: 0.9362579	test: 0.9872788	best: 0.9872788 (48)	total: 58.8s	remaining: 1m 1s
# 49:	learn: 0.9254379	test: 0.9773264	best: 0.9773264 (49)	total: 1m	remaining: 1m
# 50:	learn: 0.9169630	test: 0.9695803	best: 0.9695803 (50)	total: 1m 1s	remaining: 59s
# 51:	learn: 0.9102541	test: 0.9635790	best: 0.9635790 (51)	total: 1m 2s	remaining: 57.9s
# 52:	learn: 0.9002900	test: 0.9542635	best: 0.9542635 (52)	total: 1m 4s	remaining: 56.8s
# 53:	learn: 0.8922383	test: 0.9470750	best: 0.9470750 (53)	total: 1m 5s	remaining: 55.7s
# 54:	learn: 0.8829775	test: 0.9384695	best: 0.9384695 (54)	total: 1m 6s	remaining: 54.5s
# 55:	learn: 0.8768815	test: 0.9332593	best: 0.9332593 (55)	total: 1m 7s	remaining: 53.3s
# 56:	learn: 0.8663033	test: 0.9233066	best: 0.9233066 (56)	total: 1m 9s	remaining: 52.2s
# 57:	learn: 0.8590199	test: 0.9162376	best: 0.9162376 (57)	total: 1m 10s	remaining: 51s
# 58:	learn: 0.8514366	test: 0.9092091	best: 0.9092091 (58)	total: 1m 11s	remaining: 49.8s
# 59:	learn: 0.8440937	test: 0.9022651	best: 0.9022651 (59)	total: 1m 12s	remaining: 48.6s
# 60:	learn: 0.8347619	test: 0.8936758	best: 0.8936758 (60)	total: 1m 14s	remaining: 47.3s
# 61:	learn: 0.8290272	test: 0.8886900	best: 0.8886900 (61)	total: 1m 15s	remaining: 46.1s
# 62:	learn: 0.8201867	test: 0.8804852	best: 0.8804852 (62)	total: 1m 16s	remaining: 44.9s
# 63:	learn: 0.8155902	test: 0.8762101	best: 0.8762101 (63)	total: 1m 17s	remaining: 43.6s
# 64:	learn: 0.8090901	test: 0.8702694	best: 0.8702694 (64)	total: 1m 18s	remaining: 42.4s
# 65:	learn: 0.8023393	test: 0.8644877	best: 0.8644877 (65)	total: 1m 19s	remaining: 41.2s
# 66:	learn: 0.7952288	test: 0.8577724	best: 0.8577724 (66)	total: 1m 21s	remaining: 40s
# 67:	learn: 0.7899039	test: 0.8531802	best: 0.8531802 (67)	total: 1m 22s	remaining: 38.7s
# 68:	learn: 0.7829134	test: 0.8469628	best: 0.8469628 (68)	total: 1m 23s	remaining: 37.5s
# 69:	learn: 0.7774203	test: 0.8420711	best: 0.8420711 (69)	total: 1m 24s	remaining: 36.3s
# 70:	learn: 0.7703056	test: 0.8356881	best: 0.8356881 (70)	total: 1m 25s	remaining: 35.1s
# 71:	learn: 0.7648236	test: 0.8305438	best: 0.8305438 (71)	total: 1m 27s	remaining: 33.9s
# 72:	learn: 0.7615952	test: 0.8277185	best: 0.8277185 (72)	total: 1m 28s	remaining: 32.7s
# 73:	learn: 0.7551869	test: 0.8223215	best: 0.8223215 (73)	total: 1m 29s	remaining: 31.5s
# 74:	learn: 0.7518863	test: 0.8194556	best: 0.8194556 (74)	total: 1m 30s	remaining: 30.3s
# 75:	learn: 0.7496640	test: 0.8175236	best: 0.8175236 (75)	total: 1m 32s	remaining: 29.1s
# 76:	learn: 0.7475868	test: 0.8155805	best: 0.8155805 (76)	total: 1m 33s	remaining: 27.9s
# 77:	learn: 0.7437675	test: 0.8125417	best: 0.8125417 (77)	total: 1m 34s	remaining: 26.7s
# 78:	learn: 0.7378714	test: 0.8073314	best: 0.8073314 (78)	total: 1m 35s	remaining: 25.5s
# 79:	learn: 0.7304027	test: 0.8006795	best: 0.8006795 (79)	total: 1m 36s	remaining: 24.2s
# 80:	learn: 0.7237438	test: 0.7944494	best: 0.7944494 (80)	total: 1m 38s	remaining: 23s
# 81:	learn: 0.7211735	test: 0.7921209	best: 0.7921209 (81)	total: 1m 39s	remaining: 21.8s
# 82:	learn: 0.7187062	test: 0.7900249	best: 0.7900249 (82)	total: 1m 40s	remaining: 20.6s
# 83:	learn: 0.7160337	test: 0.7879492	best: 0.7879492 (83)	total: 1m 42s	remaining: 19.4s
# 84:	learn: 0.7124111	test: 0.7848007	best: 0.7848007 (84)	total: 1m 43s	remaining: 18.2s
# 85:	learn: 0.7093121	test: 0.7818555	best: 0.7818555 (85)	total: 1m 44s	remaining: 17s
# 86:	learn: 0.7033256	test: 0.7763780	best: 0.7763780 (86)	total: 1m 45s	remaining: 15.8s
# 87:	learn: 0.6990927	test: 0.7726963	best: 0.7726963 (87)	total: 1m 47s	remaining: 14.6s
# 88:	learn: 0.6945840	test: 0.7690464	best: 0.7690464 (88)	total: 1m 48s	remaining: 13.4s
# 89:	learn: 0.6904055	test: 0.7654395	best: 0.7654395 (89)	total: 1m 49s	remaining: 12.2s
# 90:	learn: 0.6870130	test: 0.7624924	best: 0.7624924 (90)	total: 1m 51s	remaining: 11s
# 91:	learn: 0.6843115	test: 0.7604180	best: 0.7604180 (91)	total: 1m 52s	remaining: 9.77s
# 92:	learn: 0.6806153	test: 0.7572312	best: 0.7572312 (92)	total: 1m 53s	remaining: 8.54s
# 93:	learn: 0.6759261	test: 0.7533367	best: 0.7533367 (93)	total: 1m 54s	remaining: 7.32s
# 94:	learn: 0.6735355	test: 0.7513997	best: 0.7513997 (94)	total: 1m 55s	remaining: 6.1s
# 95:	learn: 0.6701684	test: 0.7487347	best: 0.7487347 (95)	total: 1m 57s	remaining: 4.88s
# 96:	learn: 0.6673838	test: 0.7462042	best: 0.7462042 (96)	total: 1m 58s	remaining: 3.66s
# 97:	learn: 0.6636359	test: 0.7426916	best: 0.7426916 (97)	total: 1m 59s	remaining: 2.44s
# 98:	learn: 0.6587620	test: 0.7386659	best: 0.7386659 (98)	total: 2m	remaining: 1.22s
# 99:	learn: 0.6562599	test: 0.7363433	best: 0.7363433 (99)	total: 2m 1s	remaining: 0us
#
# bestTest = 0.7363433061
# bestIteration = 99
#
# 0.8293281567262423
# 0.8
# 0:	learn: 2.9363998	test: 2.9413261	best: 2.9413261 (0)	total: 1.15s	remaining: 1m 54s
# 1:	learn: 2.7312270	test: 2.7362671	best: 2.7362671 (1)	total: 2.32s	remaining: 1m 53s
# 2:	learn: 2.5567083	test: 2.5608053	best: 2.5608053 (2)	total: 3.5s	remaining: 1m 53s
# 3:	learn: 2.4282372	test: 2.4334119	best: 2.4334119 (3)	total: 4.7s	remaining: 1m 52s
# 4:	learn: 2.3207331	test: 2.3276129	best: 2.3276129 (4)	total: 5.87s	remaining: 1m 51s
# 5:	learn: 2.2174638	test: 2.2239622	best: 2.2239622 (5)	total: 7.05s	remaining: 1m 50s
# 6:	learn: 2.1223831	test: 2.1278593	best: 2.1278593 (6)	total: 8.23s	remaining: 1m 49s
# 7:	learn: 2.0429075	test: 2.0494984	best: 2.0494984 (7)	total: 9.42s	remaining: 1m 48s
# 8:	learn: 1.9709692	test: 1.9782221	best: 1.9782221 (8)	total: 10.6s	remaining: 1m 47s
# 9:	learn: 1.9027467	test: 1.9121374	best: 1.9121374 (9)	total: 11.8s	remaining: 1m 46s
# 10:	learn: 1.8425219	test: 1.8539942	best: 1.8539942 (10)	total: 13s	remaining: 1m 45s
# 11:	learn: 1.7872791	test: 1.7998480	best: 1.7998480 (11)	total: 14.2s	remaining: 1m 43s
# 12:	learn: 1.7334506	test: 1.7467051	best: 1.7467051 (12)	total: 15.4s	remaining: 1m 43s
# 13:	learn: 1.6899011	test: 1.7036065	best: 1.7036065 (13)	total: 16.7s	remaining: 1m 42s
# 14:	learn: 1.6402480	test: 1.6547857	best: 1.6547857 (14)	total: 17.9s	remaining: 1m 41s
# 15:	learn: 1.6050356	test: 1.6203117	best: 1.6203117 (15)	total: 19.1s	remaining: 1m 40s
# 16:	learn: 1.5612056	test: 1.5768622	best: 1.5768622 (16)	total: 20.4s	remaining: 1m 39s
# 17:	learn: 1.5201197	test: 1.5373233	best: 1.5373233 (17)	total: 21.6s	remaining: 1m 38s
# 18:	learn: 1.4869622	test: 1.5049444	best: 1.5049444 (18)	total: 22.7s	remaining: 1m 36s
# 19:	learn: 1.4521711	test: 1.4712413	best: 1.4712413 (19)	total: 23.9s	remaining: 1m 35s
# 20:	learn: 1.4261642	test: 1.4447102	best: 1.4447102 (20)	total: 25.1s	remaining: 1m 34s
# 21:	learn: 1.3981136	test: 1.4176388	best: 1.4176388 (21)	total: 26.3s	remaining: 1m 33s
# 22:	learn: 1.3699801	test: 1.3900465	best: 1.3900465 (22)	total: 27.5s	remaining: 1m 31s
# 23:	learn: 1.3408203	test: 1.3610149	best: 1.3610149 (23)	total: 28.7s	remaining: 1m 30s
# 24:	learn: 1.3144509	test: 1.3355928	best: 1.3355928 (24)	total: 29.9s	remaining: 1m 29s
# 25:	learn: 1.2899319	test: 1.3117583	best: 1.3117583 (25)	total: 31.1s	remaining: 1m 28s
# 26:	learn: 1.2671607	test: 1.2896162	best: 1.2896162 (26)	total: 32.3s	remaining: 1m 27s
# 27:	learn: 1.2428523	test: 1.2662772	best: 1.2662772 (27)	total: 33.5s	remaining: 1m 26s
# 28:	learn: 1.2210308	test: 1.2445801	best: 1.2445801 (28)	total: 34.6s	remaining: 1m 24s
# 29:	learn: 1.2020251	test: 1.2265389	best: 1.2265389 (29)	total: 35.8s	remaining: 1m 23s
# 30:	learn: 1.1838825	test: 1.2088703	best: 1.2088703 (30)	total: 37s	remaining: 1m 22s
# 31:	learn: 1.1656785	test: 1.1914781	best: 1.1914781 (31)	total: 38.3s	remaining: 1m 21s
# 32:	learn: 1.1479184	test: 1.1743270	best: 1.1743270 (32)	total: 39.5s	remaining: 1m 20s
# 33:	learn: 1.1317133	test: 1.1594400	best: 1.1594400 (33)	total: 40.7s	remaining: 1m 19s
# 34:	learn: 1.1158593	test: 1.1447363	best: 1.1447363 (34)	total: 42s	remaining: 1m 18s
# 35:	learn: 1.0979954	test: 1.1277772	best: 1.1277772 (35)	total: 43.2s	remaining: 1m 16s
# 36:	learn: 1.0797737	test: 1.1112555	best: 1.1112555 (36)	total: 44.4s	remaining: 1m 15s
# 37:	learn: 1.0672869	test: 1.0994405	best: 1.0994405 (37)	total: 45.6s	remaining: 1m 14s
# 38:	learn: 1.0495987	test: 1.0826438	best: 1.0826438 (38)	total: 46.8s	remaining: 1m 13s
# 39:	learn: 1.0372946	test: 1.0705791	best: 1.0705791 (39)	total: 48s	remaining: 1m 11s
# 40:	learn: 1.0253135	test: 1.0592757	best: 1.0592757 (40)	total: 49.2s	remaining: 1m 10s
# 41:	learn: 1.0110292	test: 1.0456331	best: 1.0456331 (41)	total: 50.3s	remaining: 1m 9s
# 42:	learn: 0.9963569	test: 1.0319689	best: 1.0319689 (42)	total: 51.5s	remaining: 1m 8s
# 43:	learn: 0.9818564	test: 1.0186248	best: 1.0186248 (43)	total: 52.7s	remaining: 1m 7s
# 44:	learn: 0.9710950	test: 1.0076310	best: 1.0076310 (44)	total: 53.9s	remaining: 1m 5s
# 45:	learn: 0.9580166	test: 0.9957039	best: 0.9957039 (45)	total: 55.1s	remaining: 1m 4s
# 46:	learn: 0.9492252	test: 0.9875216	best: 0.9875216 (46)	total: 56.3s	remaining: 1m 3s
# 47:	learn: 0.9401126	test: 0.9790202	best: 0.9790202 (47)	total: 57.5s	remaining: 1m 2s
# 48:	learn: 0.9325839	test: 0.9718503	best: 0.9718503 (48)	total: 58.7s	remaining: 1m 1s
# 49:	learn: 0.9223062	test: 0.9618457	best: 0.9618457 (49)	total: 59.9s	remaining: 59.9s
# 50:	learn: 0.9131871	test: 0.9531451	best: 0.9531451 (50)	total: 1m 1s	remaining: 58.7s
# 51:	learn: 0.9049767	test: 0.9457219	best: 0.9457219 (51)	total: 1m 2s	remaining: 57.4s
# 52:	learn: 0.8960944	test: 0.9377769	best: 0.9377769 (52)	total: 1m 3s	remaining: 56.2s
# 53:	learn: 0.8882955	test: 0.9300773	best: 0.9300773 (53)	total: 1m 4s	remaining: 55s
# 54:	learn: 0.8801862	test: 0.9228697	best: 0.9228697 (54)	total: 1m 5s	remaining: 53.8s
# 55:	learn: 0.8728290	test: 0.9159748	best: 0.9159748 (55)	total: 1m 6s	remaining: 52.6s
# 56:	learn: 0.8660134	test: 0.9099037	best: 0.9099037 (56)	total: 1m 8s	remaining: 51.4s
# 57:	learn: 0.8548926	test: 0.9000126	best: 0.9000126 (57)	total: 1m 9s	remaining: 50.2s
# 58:	learn: 0.8478692	test: 0.8936982	best: 0.8936982 (58)	total: 1m 10s	remaining: 49.1s
# 59:	learn: 0.8408449	test: 0.8871249	best: 0.8871249 (59)	total: 1m 11s	remaining: 47.9s
# 60:	learn: 0.8317992	test: 0.8783782	best: 0.8783782 (60)	total: 1m 13s	remaining: 46.7s
# 61:	learn: 0.8264673	test: 0.8735558	best: 0.8735558 (61)	total: 1m 14s	remaining: 45.6s
# 62:	learn: 0.8207037	test: 0.8682283	best: 0.8682283 (62)	total: 1m 15s	remaining: 44.4s
# 63:	learn: 0.8139421	test: 0.8621942	best: 0.8621942 (63)	total: 1m 16s	remaining: 43.3s
# 64:	learn: 0.8074551	test: 0.8565569	best: 0.8565569 (64)	total: 1m 18s	remaining: 42.1s
# 65:	learn: 0.8005270	test: 0.8501371	best: 0.8501371 (65)	total: 1m 19s	remaining: 40.9s
# 66:	learn: 0.7947535	test: 0.8450483	best: 0.8450483 (66)	total: 1m 20s	remaining: 39.8s
# 67:	learn: 0.7895383	test: 0.8402398	best: 0.8402398 (67)	total: 1m 21s	remaining: 38.6s
# 68:	learn: 0.7842047	test: 0.8356017	best: 0.8356017 (68)	total: 1m 23s	remaining: 37.4s
# 69:	learn: 0.7765935	test: 0.8288635	best: 0.8288635 (69)	total: 1m 24s	remaining: 36.2s
# 70:	learn: 0.7725095	test: 0.8250389	best: 0.8250389 (70)	total: 1m 25s	remaining: 35s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_31167/2389478003.py in <module>
#      37     #                              cv=5, scoring='accuracy', verbose=1)
#      38
# ---> 39     model.fit(train_dataset,
#      40               eval_set=eval_dataset)
#      41
#
# ~/ml/envML/lib/python3.9/site-packages/catboost/core.py in fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    4919             CatBoostClassifier._check_is_compatible_loss(params['loss_function'])
#    4920
# -> 4921         self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    4922                   eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period,
#    4923                   silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# ~/ml/envML/lib/python3.9/site-packages/catboost/core.py in _fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2190         with log_fixup(log_cout, log_cerr), \
#    2191             plot_wrapper(plot, [_get_train_dir(self.get_params())]):
# -> 2192             self._train(
#    2193                 train_pool,
#    2194                 train_params["eval_sets"],
#
# ~/ml/envML/lib/python3.9/site-packages/catboost/core.py in _train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1617
#    1618     def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1619         self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1620         self._set_trained_model_attributes()
#    1621
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
from catboost import cv

params = {
    'loss_function': 'MultiClass',
    'iterations': 10,
    'custom_loss': 'AUC',
    # 'random_seed': 63,
    'learning_rate': 0.1,
    'depth': 6
}

cv_data = cv(
    params=params,
    pool=Pool(X_train, label=y_train),
    fold_count=5,  # Разбивка выборки на 5 кусочков
    shuffle=True,  # Перемешаем наши данные
    # partition_random_seed=0,
    # plot=True, # Никуда без визуализатора
    # stratified=True,
    # verbose=False
)
# Out:
# Training on fold [0/5]
# 0:	learn: 2.9366505	test: 2.9415135	best: 2.9415135 (0)	total: 1.24s	remaining: 11.2s
# 1:	learn: 2.7262990	test: 2.7351214	best: 2.7351214 (1)	total: 2.53s	remaining: 10.1s
# 2:	learn: 2.5690359	test: 2.5828843	best: 2.5828843 (2)	total: 3.77s	remaining: 8.81s
# 3:	learn: 2.4263310	test: 2.4425620	best: 2.4425620 (3)	total: 5.04s	remaining: 7.56s
# 4:	learn: 2.3088246	test: 2.3273819	best: 2.3273819 (4)	total: 6.29s	remaining: 6.29s
# 5:	learn: 2.2066776	test: 2.2272465	best: 2.2272465 (5)	total: 7.54s	remaining: 5.03s
# 6:	learn: 2.1160191	test: 2.1384954	best: 2.1384954 (6)	total: 8.79s	remaining: 3.77s
# 7:	learn: 2.0300570	test: 2.0549725	best: 2.0549725 (7)	total: 10.1s	remaining: 2.54s
# 8:	learn: 1.9516631	test: 1.9777278	best: 1.9777278 (8)	total: 11.4s	remaining: 1.27s
# 9:	learn: 1.8837237	test: 1.9105692	best: 1.9105692 (9)	total: 12.7s	remaining: 0us
#
# bestTest = 1.910569227
# bestIteration = 9
#
# Training on fold [1/5]
# 0:	learn: 2.9332102	test: 2.9402335	best: 2.9402335 (0)	total: 1.37s	remaining: 12.3s
# 1:	learn: 2.7216875	test: 2.7324301	best: 2.7324301 (1)	total: 2.62s	remaining: 10.5s
# 2:	learn: 2.5662212	test: 2.5795084	best: 2.5795084 (2)	total: 3.89s	remaining: 9.08s
# 3:	learn: 2.4284832	test: 2.4449662	best: 2.4449662 (3)	total: 5.16s	remaining: 7.73s
# 4:	learn: 2.3110004	test: 2.3271542	best: 2.3271542 (4)	total: 6.5s	remaining: 6.5s
# 5:	learn: 2.2043054	test: 2.2211531	best: 2.2211531 (5)	total: 7.88s	remaining: 5.25s
# 6:	learn: 2.1114217	test: 2.1306414	best: 2.1306414 (6)	total: 9.15s	remaining: 3.92s
# 7:	learn: 2.0256775	test: 2.0459223	best: 2.0459223 (7)	total: 10.4s	remaining: 2.61s
# 8:	learn: 1.9491929	test: 1.9712663	best: 1.9712663 (8)	total: 11.7s	remaining: 1.3s
# 9:	learn: 1.8859917	test: 1.9091763	best: 1.9091763 (9)	total: 13s	remaining: 0us
#
# bestTest = 1.909176254
# bestIteration = 9
#
# Training on fold [2/5]
# 0:	learn: 2.9664917	test: 2.9706263	best: 2.9706263 (0)	total: 1.23s	remaining: 11.1s
# 1:	learn: 2.7512828	test: 2.7614985	best: 2.7614985 (1)	total: 2.67s	remaining: 10.7s
# 2:	learn: 2.5808675	test: 2.5903620	best: 2.5903620 (2)	total: 3.95s	remaining: 9.22s
# 3:	learn: 2.4276668	test: 2.4357063	best: 2.4357063 (3)	total: 5.2s	remaining: 7.81s
# 4:	learn: 2.3110361	test: 2.3200508	best: 2.3200508 (4)	total: 6.49s	remaining: 6.49s
# 5:	learn: 2.2137746	test: 2.2232924	best: 2.2232924 (5)	total: 7.72s	remaining: 5.15s
# 6:	learn: 2.1209967	test: 2.1320135	best: 2.1320135 (6)	total: 9s	remaining: 3.85s
# 7:	learn: 2.0425576	test: 2.0541634	best: 2.0541634 (7)	total: 10.3s	remaining: 2.56s
# 8:	learn: 1.9683534	test: 1.9814776	best: 1.9814776 (8)	total: 11.5s	remaining: 1.28s
# 9:	learn: 1.9035938	test: 1.9179800	best: 1.9179800 (9)	total: 12.8s	remaining: 0us
#
# bestTest = 1.917979966
# bestIteration = 9
#
# Training on fold [3/5]
# 0:	learn: 2.9292010	test: 2.9328898	best: 2.9328898 (0)	total: 1.35s	remaining: 12.2s
# 1:	learn: 2.7060991	test: 2.7136468	best: 2.7136468 (1)	total: 2.73s	remaining: 10.9s
# 2:	learn: 2.5424636	test: 2.5519657	best: 2.5519657 (2)	total: 4.02s	remaining: 9.38s
# 3:	learn: 2.4002852	test: 2.4101926	best: 2.4101926 (3)	total: 5.28s	remaining: 7.92s
# 4:	learn: 2.2879317	test: 2.2988333	best: 2.2988333 (4)	total: 6.58s	remaining: 6.58s
# 5:	learn: 2.1898450	test: 2.2040461	best: 2.2040461 (5)	total: 7.87s	remaining: 5.24s
# 6:	learn: 2.1007492	test: 2.1165339	best: 2.1165339 (6)	total: 9.25s	remaining: 3.96s
# 7:	learn: 2.0175863	test: 2.0351242	best: 2.0351242 (7)	total: 10.7s	remaining: 2.68s
# 8:	learn: 1.9485474	test: 1.9675014	best: 1.9675014 (8)	total: 12.2s	remaining: 1.36s
# 9:	learn: 1.8740088	test: 1.8946739	best: 1.8946739 (9)	total: 13.9s	remaining: 0us
#
# bestTest = 1.89467386
# bestIteration = 9
#
# Training on fold [4/5]
# 0:	learn: 2.9234410	test: 2.9240646	best: 2.9240646 (0)	total: 1.35s	remaining: 12.2s
# 1:	learn: 2.7106773	test: 2.7088618	best: 2.7088618 (1)	total: 2.68s	remaining: 10.7s
# 2:	learn: 2.5477946	test: 2.5467786	best: 2.5467786 (2)	total: 4s	remaining: 9.35s
# 3:	learn: 2.4101186	test: 2.4084205	best: 2.4084205 (3)	total: 5.41s	remaining: 8.12s
# 4:	learn: 2.2995475	test: 2.3002759	best: 2.3002759 (4)	total: 6.68s	remaining: 6.68s
# 5:	learn: 2.2053221	test: 2.2058321	best: 2.2058321 (5)	total: 7.98s	remaining: 5.32s
# 6:	learn: 2.1170203	test: 2.1183989	best: 2.1183989 (6)	total: 9.25s	remaining: 3.96s
# 7:	learn: 2.0387812	test: 2.0402584	best: 2.0402584 (7)	total: 10.8s	remaining: 2.71s
# 8:	learn: 1.9662606	test: 1.9688383	best: 1.9688383 (8)	total: 12.3s	remaining: 1.37s
# 9:	learn: 1.8998492	test: 1.9037681	best: 1.9037681 (9)	total: 13.8s	remaining: 0us
#
# bestTest = 1.903768093
# bestIteration = 9

# %%
print(cv_data)
# Out:
#    iterations  test-MultiClass-mean  test-MultiClass-std  \
# 0           0              2.941866             0.017517
# 1           1              2.730312             0.020845
# 2           2              2.570300             0.019590
# 3           3              2.428370             0.017742
# 4           4              2.314739             0.014181
# 5           5              2.216314             0.010630
# 6           6              2.127217             0.009405
# 7           7              2.046088             0.008637
# 8           8              1.973362             0.006003
# 9           9              1.907233             0.008662
#
#    train-MultiClass-mean  train-MultiClass-std  test-AUC-mean  test-AUC-std
# 0               2.937799              0.016776            NaN           NaN
# 1               2.723209              0.017676            NaN           NaN
# 2               2.561277              0.015844            NaN           NaN
# 3               2.418577              0.012718            NaN           NaN
# 4               2.303668              0.009991            NaN           NaN
# 5               2.203985              0.008731            NaN           NaN
# 6               2.113241              0.007770            NaN           NaN
# 7               2.030932              0.010041            NaN           NaN
# 8               1.956803              0.009687            NaN           NaN
# 9               1.889433              0.012159            NaN           NaN
